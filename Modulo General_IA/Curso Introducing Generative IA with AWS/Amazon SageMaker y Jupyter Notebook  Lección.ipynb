# %% [markdown]
# # Amazon SageMaker y Jupyter Notebook
#
# demostraremos cómo funciona Amazon SageMaker en el entorno de Jupyter Notebook en la consola de Amazon.
#
# en este ejemplo construremos un chatbot simple con **Amazon SageMaker** esta es una herramienta versatil y ideal para principiantes como para expertos en ml, simplifica el
#  proceso de creacion, entrenamiento e implementacion de modelos de ml
#
# # ![image.png](attachment:image.png)#
